# %% [markdown]
# <a href="https://colab.research.google.com/github/tahreem636/restaurants-dataset-bengaluru/blob/main/Bengaluru_Restaurants.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']='/CONTENT/'

# %%
# !kaggle datasets download -d mrmars1010/restaurants-dataset-bengaluru
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mrmars1010/restaurants-dataset-bengaluru
# License(s): CC0-1.0
# ...
#   0% 0.00/792k [00:00<?, ?B/s]
# 100% 792k/792k [00:00<00:00, 103MB/s]

# %%
import pandas as pd
df = pd.read_csv('restaurants-dataset-bengaluru.zip')
df
# Out:
#                                               name  \
# 0     Absolute Barbecues - Marathahalli, Bengaluru
# 1                            Cuppa Redefined - HSR
# 2                                    Bharjari Oota
# 3                                 The Big Barbeque
# 4                               Savoury Restaurant
# ...                                            ...
# 9286                             Pizza Plus Nadiad
# 9287                                Iyengar Bakery
# 9288                             Indian Coffee Bar
# 9289                                Kanaka Darshan
# 9290                                    Desi Dhaba
#
#                                                 address addressObj/country  \
# 0     3rd Floor, 90/4, Marathahalli Outer Ring Road ...              India
# 1     1237, Sri Sai Crystal 17th Cross 5th Main Rd, ...              India
# 2     18, Gandhi Bazar Main Road Basavanagudi, Benga...              India
# ...

# %%
# !kaggle datasets download -d prokshitha/restaurants-dataset-bengaluru.zip
# Out:
# 403 - Forbidden - Permission 'datasets.get' was denied

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  restaurants-dataset-bengaluru.zip
#   inflating: Bengaluru_Restaurants.csv

# %%
df1=pd.read_csv('Bengaluru_Restaurants.csv')
df1.head()
# Out:
#                                            name  \
# 0  Absolute Barbecues - Marathahalli, Bengaluru
# 1                         Cuppa Redefined - HSR
# 2                                 Bharjari Oota
# 3                              The Big Barbeque
# 4                            Savoury Restaurant
#
#                                              address addressObj/country  \
# 0  3rd Floor, 90/4, Marathahalli Outer Ring Road ...              India
# 1  1237, Sri Sai Crystal 17th Cross 5th Main Rd, ...              India
# 2  18, Gandhi Bazar Main Road Basavanagudi, Benga...              India
# 3  No 163, 2nd Floor, Above Adyar Ananda Bhavan N...              India
# 4  27 Mosque Road Next to Sangeetha Mobiles, Beng...              India
#
#   addressObj/postalcode addressObj/state  \
# 0                560037        Karnataka
# 1                560102        Karnataka
# 2                560004        Karnataka
# 3                560100        Karnataka
# ...
